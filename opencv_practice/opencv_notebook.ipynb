# %%
import cv2
from matplotlib import pyplot as plt

# %%
# read in image
# read as grayscale (argument 0) or RGB (argument -1)
img=cv2.imread(r"D:\dev\practice_workspace\opencv_practice\resources\galaxy.jpg",0)

# %%
print(type(img))
print(img)
# Out:
# <class 'numpy.ndarray'>
# [[14 18 14 ... 20 15 16]
#  [12 16 12 ... 20 15 17]
#  [12 13 16 ... 14 24 21]
#  ...
#  [ 0  0  0 ...  5  8 14]
#  [ 0  0  0 ...  2  3  9]
#  [ 1  1  1 ...  1  1  3]]

# %%
plt.imshow(img)
plt.title('my picture')
plt.show()

# %%
cv2.imshow("Galaxy", img)   # display the image
cv2.waitKey(0)          # how long to display the image (0 implies the user presses a button)
cv2.destroyAllWindows()
